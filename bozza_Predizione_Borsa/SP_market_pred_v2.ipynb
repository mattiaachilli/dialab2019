# %% [markdown]
# # Laboratorio: Predizione Indice di Borsa (bozza)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %% [markdown]
# ## Estrazione Dati
#
# I dati storici sull'andamento di S&P 500 e altri indici di borsa sono disponibili su diversi siti specializzati, ad es. [https://finance.yahoo.com/](Yahoo! Finance)
#
# Il file `SP500-2001-2005.csv` contiene l'andamento di S&P 500 dall'inizio del 2001 alla fine del 2005

# %%
sp500 = pd.read_csv("SP500-2001-2005.csv", parse_dates=["Date"])

# %% [markdown]
# Per ottenere questo file da Yahoo! Finance abbiamo cercato il titolo "S&P 500" (simbolo GSPC), selezionato la sezione "Historical Data", filtrato sul periodo da "1/1/2001" a "12/31/2005" e cliccato su "Download Data" per scaricare il CSV

# %% [markdown]
# ## Interpretazione dei Dati

# %%
sp500.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2001-01-02  1320.280029  1320.280029  1276.050049  1283.270020  1283.270020
# 1 2001-01-03  1283.270020  1347.760010  1274.619995  1347.560059  1347.560059
# 2 2001-01-04  1347.560059  1350.239990  1329.140015  1333.339966  1333.339966
# 3 2001-01-05  1333.339966  1334.770020  1294.949951  1298.349976  1298.349976
# 4 2001-01-08  1298.349976  1298.349976  1276.290039  1295.859985  1295.859985
#
#        Volume
# 0  1129400000
# 1  1880700000
# 2  2131000000
# 3  1430800000
# 4  1115500000

# %% [markdown]
# La colonna `Date` indica la data a cui si riferisce ciascuna riga, per cui è opportuno impostarla come indice

# %%
sp500.set_index("Date", inplace=True)

# %% [markdown]
# - `Open` indica il valore del titolo all'apertura del mercato (tutti i valori sono in USD)
# - `Close` indica il valore alla chiusura del mercato (l'apertura del giorno dopo può differire)
# - `High` e `Low` indicano il valore massimo e minimo raggiunti dal titolo nell'arco della giornata
# - `Adj Close` è una versione corretta del prezzo di chiusura, in questo caso è sempre uguale a `Close`
# - `Volume` indica il numero totale di titoli scambiati durante quel giorno

# %% [markdown]
# ## Obiettivo: Prevedere Salita o Discesa del Valore
#
# Dai valori $O$ di apertura (`Open`) e $C$ di chiusura (`Close`) di ogni giorno possiamo definire la variazione percentuale del valore come
#
# $$ 100\cdot\frac{C-O}{O} $$
#
# Aggiungiamo una colonna con questo valore al dataset

# %%
sp500["PercReturn"] = 100 * (sp500["Close"] - sp500["Open"]) / sp500["Open"]

# %% [markdown]
# Il nostro obiettivo è, all'inizio di ogni giorno, prevedere se tale valore sarà positivo ($C>O$, valore in salita) o negativo ($C<O$, valore in discesa)

# %% [markdown]
# ## Estrazione delle Feature Predittive
#
# Per effettuare la predizione, servono degli indicatori il cui valore è noto all'inizio di ogni giornata: possiamo usare i valori dei giorni precedenti
#
# Il metodo `shift` crea una copia di una serie con i valori slittati in avanti di un numero di righe indicato: la usiamo per creare 5 serie con i valori della colonna `PercReturn` ritardati da 1 a 5 giorni

# %%
lagged_cols = {i: sp500["PercReturn"].shift(i) for i in range(1, 6)}

# %% [markdown]
# Creo un nuovo DataFrame `X` con questi valori

# %%
for i in range(1, 6):
    sp500["Lag{}".format(i)] = sp500["PercReturn"].shift(i)

# %%
X = pd.DataFrame({"Lag{}".format(i): ser for i, ser in lagged_cols.items()})

# %% [markdown]
# Aggiungiamo a `X` una colonna col volume del giorno precedente, diviso per un miliardo ($10^9$) per avere una scala simile alle altre colonne

# %%
X["VolumeLag1"] = sp500["Volume"].shift(1) / 1e9

# %%
X.head(7)
# Out:
#                 Lag1      Lag2      Lag3      Lag4      Lag5  VolumeLag1
# Date
# 2001-01-02       NaN       NaN       NaN       NaN       NaN         NaN
# 2001-01-03 -2.803194       NaN       NaN       NaN       NaN      1.1294
# 2001-01-04  5.009861 -2.803194       NaN       NaN       NaN      1.8807
# 2001-01-05 -1.055247  5.009861 -2.803194       NaN       NaN      2.1310
# 2001-01-08 -2.624236 -1.055247  5.009861 -2.803194       NaN      1.4308
# 2001-01-09 -0.191781 -2.624236 -1.055247  5.009861 -2.803194      1.1155
# 2001-01-10  0.381219 -0.191781 -2.624236 -1.055247  5.009861      1.1913

# %% [markdown]
# Nelle prime righe del dataset rimangono valori mancanti (_NaN_, Not a Number): usiamo il metodo `dropna` per rimuoverle le righe in cui sono presenti

# %%
X.dropna(inplace=True)

# %%
X.head(7)
# Out:
#                 Lag1      Lag2      Lag3      Lag4      Lag5  VolumeLag1
# Date
# 2001-01-09 -0.191781 -2.624236 -1.055247  5.009861 -2.803194      1.1155
# 2001-01-10  0.381219 -0.191781 -2.624236 -1.055247  5.009861      1.1913
# 2001-01-11  0.958639  0.381219 -0.191781 -2.624236 -1.055247      1.2965
# 2001-01-12  1.031770  0.958639  0.381219 -0.191781 -2.624236      1.4112
# 2001-01-16 -0.623287  1.031770  0.958639  0.381219 -0.191781      1.2760
# 2001-01-17  0.631871 -0.623287  1.031770  0.958639  0.381219      1.2057
# 2001-01-18  0.212561  0.631871 -0.623287  1.031770  0.958639      1.3491

# %% [markdown]
# Questo costituisce il set di variabili che utilizzeremo per predire la variazione giornaliera
#
# Chiamiamo `y` la serie di valori che dobbiamo predire: usiamo `reindex_like` per selezionare i valori di `PercReturn` corrispondenti alle sole righe di `X` rimaste

# %%
y = sp500["PercReturn"].reindex_like(X)

# %% [markdown]
# ## Divisione in Training e Validation Set
#
# Dividiamo i dati ottenuti in due insiemi
# - un _training set_ per addestrare i modelli di predizione
# - un _validation set_ per valutare la loro accuratezza nella predizione, in modo da selezionare quello migliore
#
# Usiamo i dati dal 2001 al 2004 (80% circa) per l'addestramento e quelli del 2005 per la validazione: creiamo un array binario `is_train` che indichi quali righe andranno nel training set piuttosto che nel validation set...

# %%
is_train = X.index.year < 2005

# %% [markdown]
# ...quindi creiamo copie di `X` e `y` con i dati suddivisi tra training e validation

# %%
X_train = X[is_train]
y_train = y[is_train]
X_val = X[~is_train]
y_val = y[~is_train]

# %% [markdown]
# ## Regressione Lineare
#
# Testiamo dapprima un semplice modello di regressione lineare per prevedere la variazione odierna `y` dagli indicatori `X`
#
# Creiamo un modello con i parametri di default

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# Addestriamo il modello con i dati di addestramento

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Otteniamo dal modello predizioni relative al validation set

# %%
y_val_pred = model.predict(X_val)

# %% [markdown]
# Per misurare l'accuratezza del modello, vediamo in quanti casi il segno della variazione + o - è previsto correttamente
#
# Estraiamo una serie con il segno corretto...

# %%
s_val = pd.Series(np.where(y_val >= 0, "Up", "Down"), index=y_val.index)

# %% [markdown]
# ...e una con il segno predetto

# %%
s_val_pred = pd.Series(np.where(y_val_pred >= 0, "Up", "Down"), index=y_val.index)

# %% [markdown]
# In che percentuale di casi i segni combaciano?

# %%
np.mean(s_val == s_val_pred)
# Out:
# 0.5317460317460317

# %% [markdown]
# ## Regressione Logistica
#
# La regressione logistica è usata per prevedere una classe piuttosto che un valore reale, la usiamo per prevedere direttamente il segno + o - della variazione

# %%
s_train = pd.Series(np.where(y_train >= 0, "Up", "Down"), index=y_train.index)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, s_train)
# Out:
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model.score(X_val, s_val)
# Out:
# 0.4642857142857143

# %%
X_train.shape, X_val.shape
# Out:
# ((999, 6), (252, 6))

# %%
X_train = X_train[["Lag1", "Lag2"]]
X_val = X_val[["Lag1", "Lag2"]]

# %%
model = LogisticRegression()

# %%
model.fit(X_train, s_train)
# Out:
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model.score(X_val, s_val)
# Out:
# 0.5753968253968254

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
model = LinearDiscriminantAnalysis()
model.fit(X_train, s_train)
model.score(X_val, s_val)
# Out:
# 0.5753968253968254

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
model = QuadraticDiscriminantAnalysis()
model.fit(X_train, s_train)
model.score(X_val, s_val)
# Out:
# 0.5753968253968254

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
model = Pipeline([
    ("poly", PolynomialFeatures(degree=10)),
    ("logreg", LogisticRegression())
])
model.fit(X_train, s_train)
model.score(X_val, s_val)
# Out:
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.5

# %%
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.metrics import make_scorer
from sklearn.kernel_ridge import KernelRidge
split = PredefinedSplit(np.where(is_train, -1, 0))
scorer = make_scorer(lambda y, p: np.mean((y>=0) == (p>=0)), greater_is_better=True)

# %%
gs = GridSearchCV(KernelRidge(), param_grid=[
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["linear"]},
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["poly"], "degree": np.linspace(2, 5, 4)},
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["rbf"], "gamma": np.logspace(-4, 4, 5)}
], cv=split, scoring=scorer)
gs.fit(X[["Lag1", "Lag2"]], y)
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise-deprecating',
#        estimator=KernelRidge(alpha=1, coef0=1, degree=3, gamma=None, kernel='linear',
#       kernel_params=None),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['linear']}, {'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['poly'], 'degree': array([2., 3., 4., 5.])}, {'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['rbf'], 'gamma': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(<lambda>), verbose=0)

# %%
pd.DataFrame(gs.cv_results_).sort_values("rank_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 35       0.043692           0.0         0.004665             0.0           1
# 28       0.094649           0.0         0.011124             0.0      0.0001
# 30       0.071652           0.0         0.009744             0.0        0.01
# 45       0.065446           0.0         0.008373             0.0       10000
# 40       0.063823           0.0         0.012050             0.0         100
# 0        0.318040           0.0         0.001367             0.0      0.0001
# 1        0.072132           0.0         0.002470             0.0        0.01
# 2        0.052242           0.0         0.002525             0.0           1
# 3        0.059884           0.0         0.001281             0.0         100
# 4        0.049757           0.0         0.002629             0.0       10000
# 38       0.088523           0.0         0.011224             0.0           1
# 41       0.075488           0.0         0.019937             0.0         100
# 46       0.068990           0.0         0.008757             0.0       10000
# 33       0.096085           0.0         0.006196             0.0        0.01
# 21       0.029695           0.0         0.001565             0.0       10000
# 48       0.123775           0.0         0.018857             0.0       10000
# 43       0.106946           0.0         0.012879             0.0         100
# 37       0.050510           0.0         0.006421             0.0           1
# 44       0.071891           0.0         0.009873             0.0         100
# 39       0.068238           0.0         0.014014             0.0           1
# 49       0.054818           0.0         0.005807             0.0       10000
# 29       0.068876           0.0         0.006374             0.0      0.0001
# 34       0.050102           0.0         0.005484             0.0        0.01
# 42       0.095284           0.0         0.014797             0.0         100
# 32       0.070838           0.0         0.013515             0.0        0.01
# 47       0.072163           0.0         0.014006             0.0       10000
# 27       0.071848           0.0         0.014900             0.0      0.0001
# 36       0.046158           0.0         0.005561             0.0           1
# 24       0.106220           0.0         0.065318             0.0       10000
# 26       0.076051           0.0         0.011276             0.0      0.0001
# 7        0.104590           0.0         0.017585             0.0      0.0001
# 11       0.128017           0.0         0.021310             0.0        0.01
# 15       0.094337           0.0         0.017485             0.0           1
# 19       0.094683           0.0         0.018239             0.0         100
# 25       0.049181           0.0         0.010878             0.0      0.0001
# 17       0.031514           0.0         0.002143             0.0         100
# 31       0.074419           0.0         0.014256             0.0        0.01
# 16       0.094187           0.0         0.017790             0.0           1
# 12       0.095999           0.0         0.017487             0.0        0.01
# 10       0.109624           0.0         0.042490             0.0        0.01
# 18       0.096322           0.0         0.017507             0.0         100
# 8        0.094429           0.0         0.017551             0.0      0.0001
# 6        0.128745           0.0         0.017511             0.0      0.0001
# 14       0.095174           0.0         0.017987             0.0           1
# 20       0.096013           0.0         0.017705             0.0         100
# 13       0.030246           0.0         0.002035             0.0           1
# 9        0.030810           0.0         0.001553             0.0        0.01
# 23       0.093304           0.0         0.017869             0.0       10000
# 5        0.056797           0.0         0.003441             0.0      0.0001
# 22       0.093879           0.0         0.017581             0.0       10000
#
#    param_kernel param_degree param_gamma  \
# 35          rbf          NaN      0.0001
# 28          rbf          NaN         100
# 30          rbf          NaN      0.0001
# 45          rbf          NaN      0.0001
# 40          rbf          NaN      0.0001
# 0        linear          NaN         NaN
# 1        linear          NaN         NaN
# 2        linear          NaN         NaN
# 3        linear          NaN         NaN
# 4        linear          NaN         NaN
# 38          rbf          NaN         100
# 41          rbf          NaN        0.01
# 46          rbf          NaN        0.01
# 33          rbf          NaN         100
# 21         poly            2         NaN
# 48          rbf          NaN         100
# 43          rbf          NaN         100
# 37          rbf          NaN           1
# 44          rbf          NaN       10000
# 39          rbf          NaN       10000
# 49          rbf          NaN       10000
# 29          rbf          NaN       10000
# 34          rbf          NaN       10000
# 42          rbf          NaN           1
# 32          rbf          NaN           1
# 47          rbf          NaN           1
# 27          rbf          NaN           1
# 36          rbf          NaN        0.01
# 24         poly            5         NaN
# 26          rbf          NaN        0.01
# 7          poly            4         NaN
# 11         poly            4         NaN
# 15         poly            4         NaN
# 19         poly            4         NaN
# 25          rbf          NaN      0.0001
# 17         poly            2         NaN
# 31          rbf          NaN        0.01
# 16         poly            5         NaN
# 12         poly            5         NaN
# 10         poly            3         NaN
# 18         poly            3         NaN
# 8          poly            5         NaN
# 6          poly            3         NaN
# 14         poly            3         NaN
# 20         poly            5         NaN
# 13         poly            2         NaN
# 9          poly            2         NaN
# 23         poly            4         NaN
# 5          poly            2         NaN
# 22         poly            3         NaN
#
#                                                params  split0_test_score  \
# 35   {'alpha': 1.0, 'gamma': 0.0001, 'kernel': 'rbf'}           0.579365
# 28  {'alpha': 0.0001, 'gamma': 100.0, 'kernel': 'r...           0.567460
# 30  {'alpha': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}           0.563492
# 45  {'alpha': 10000.0, 'gamma': 0.0001, 'kernel': ...           0.559524
# 40  {'alpha': 100.0, 'gamma': 0.0001, 'kernel': 'r...           0.559524
# 0               {'alpha': 0.0001, 'kernel': 'linear'}           0.551587
# 1                 {'alpha': 0.01, 'kernel': 'linear'}           0.551587
# 2                  {'alpha': 1.0, 'kernel': 'linear'}           0.551587
# 3                {'alpha': 100.0, 'kernel': 'linear'}           0.551587
# 4              {'alpha': 10000.0, 'kernel': 'linear'}           0.551587
# 38    {'alpha': 1.0, 'gamma': 100.0, 'kernel': 'rbf'}           0.527778
# 41   {'alpha': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}           0.527778
# 46  {'alpha': 10000.0, 'gamma': 0.01, 'kernel': 'r...           0.527778
# 33   {'alpha': 0.01, 'gamma': 100.0, 'kernel': 'rbf'}           0.523810
# 21  {'alpha': 10000.0, 'degree': 2.0, 'kernel': 'p...           0.523810
# 48  {'alpha': 10000.0, 'gamma': 100.0, 'kernel': '...           0.519841
# 43  {'alpha': 100.0, 'gamma': 100.0, 'kernel': 'rbf'}           0.519841
# 37      {'alpha': 1.0, 'gamma': 1.0, 'kernel': 'rbf'}           0.500000
# 44  {'alpha': 100.0, 'gamma': 10000.0, 'kernel': '...           0.500000
# 39  {'alpha': 1.0, 'gamma': 10000.0, 'kernel': 'rbf'}           0.500000
# 49  {'alpha': 10000.0, 'gamma': 10000.0, 'kernel':...           0.500000
# 29  {'alpha': 0.0001, 'gamma': 10000.0, 'kernel': ...           0.496032
# 34  {'alpha': 0.01, 'gamma': 10000.0, 'kernel': 'r...           0.496032
# 42    {'alpha': 100.0, 'gamma': 1.0, 'kernel': 'rbf'}           0.492063
# 32     {'alpha': 0.01, 'gamma': 1.0, 'kernel': 'rbf'}           0.488095
# 47  {'alpha': 10000.0, 'gamma': 1.0, 'kernel': 'rbf'}           0.476190
# 27   {'alpha': 0.0001, 'gamma': 1.0, 'kernel': 'rbf'}           0.476190
# 36     {'alpha': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}           0.464286
# 24  {'alpha': 10000.0, 'degree': 5.0, 'kernel': 'p...           0.452381
# 26  {'alpha': 0.0001, 'gamma': 0.01, 'kernel': 'rbf'}           0.452381
# 7   {'alpha': 0.0001, 'degree': 4.0, 'kernel': 'po...           0.448413
# 11   {'alpha': 0.01, 'degree': 4.0, 'kernel': 'poly'}           0.448413
# 15    {'alpha': 1.0, 'degree': 4.0, 'kernel': 'poly'}           0.448413
# 19  {'alpha': 100.0, 'degree': 4.0, 'kernel': 'poly'}           0.448413
# 25  {'alpha': 0.0001, 'gamma': 0.0001, 'kernel': '...           0.448413
# 17  {'alpha': 100.0, 'degree': 2.0, 'kernel': 'poly'}           0.444444
# 31    {'alpha': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}           0.444444
# 16    {'alpha': 1.0, 'degree': 5.0, 'kernel': 'poly'}           0.440476
# 12   {'alpha': 0.01, 'degree': 5.0, 'kernel': 'poly'}           0.440476
# 10   {'alpha': 0.01, 'degree': 3.0, 'kernel': 'poly'}           0.440476
# 18  {'alpha': 100.0, 'degree': 3.0, 'kernel': 'poly'}           0.440476
# 8   {'alpha': 0.0001, 'degree': 5.0, 'kernel': 'po...           0.440476
# 6   {'alpha': 0.0001, 'degree': 3.0, 'kernel': 'po...           0.440476
# 14    {'alpha': 1.0, 'degree': 3.0, 'kernel': 'poly'}           0.440476
# 20  {'alpha': 100.0, 'degree': 5.0, 'kernel': 'poly'}           0.432540
# 13    {'alpha': 1.0, 'degree': 2.0, 'kernel': 'poly'}           0.432540
# 9    {'alpha': 0.01, 'degree': 2.0, 'kernel': 'poly'}           0.432540
# 23  {'alpha': 10000.0, 'degree': 4.0, 'kernel': 'p...           0.432540
# 5   {'alpha': 0.0001, 'degree': 2.0, 'kernel': 'po...           0.432540
# 22  {'alpha': 10000.0, 'degree': 3.0, 'kernel': 'p...           0.408730
#
#     mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 35         0.579365             0.0                1            0.517518
# 28         0.567460             0.0                2            0.992993
# 30         0.563492             0.0                3            0.527528
# 45         0.559524             0.0                4            0.506507
# 40         0.559524             0.0                4            0.506507
# 0          0.551587             0.0                6            0.521522
# 1          0.551587             0.0                6            0.521522
# 2          0.551587             0.0                6            0.521522
# 3          0.551587             0.0                6            0.521522
# 4          0.551587             0.0                6            0.520521
# 38         0.527778             0.0               11            0.826827
# 41         0.527778             0.0               11            0.531532
# 46         0.527778             0.0               11            0.524525
# 33         0.523810             0.0               14            0.960961
# 21         0.523810             0.0               14            0.518519
# 48         0.519841             0.0               16            0.766767
# 43         0.519841             0.0               16            0.767768
# 37         0.500000             0.0               18            0.571572
# 44         0.500000             0.0               18            0.993994
# 39         0.500000             0.0               18            0.994995
# 49         0.500000             0.0               18            0.993994
# 29         0.496032             0.0               22            1.000000
# 34         0.496032             0.0               22            0.997998
# 42         0.492063             0.0               24            0.571572
# 32         0.488095             0.0               25            0.604605
# 47         0.476190             0.0               26            0.559560
# 27         0.476190             0.0               26            0.628629
# 36         0.464286             0.0               28            0.512513
# 24         0.452381             0.0               29            0.526527
# 26         0.452381             0.0               29            0.524525
# 7          0.448413             0.0               31            0.522523
# 11         0.448413             0.0               31            0.522523
# 15         0.448413             0.0               31            0.522523
# 19         0.448413             0.0               31            0.519520
# 25         0.448413             0.0               31            0.511512
# 17         0.444444             0.0               36            0.511512
# 31         0.444444             0.0               36            0.518519
# 16         0.440476             0.0               38            0.529530
# 12         0.440476             0.0               38            0.529530
# 10         0.440476             0.0               38            0.517518
# 18         0.440476             0.0               38            0.519520
# 8          0.440476             0.0               38            0.529530
# 6          0.440476             0.0               38            0.517518
# 14         0.440476             0.0               38            0.517518
# 20         0.432540             0.0               45            0.527528
# 13         0.432540             0.0               45            0.512513
# 9          0.432540             0.0               45            0.512513
# 23         0.432540             0.0               45            0.502503
# 5          0.432540             0.0               45            0.512513
# 22         0.408730             0.0               50            0.508509
#
#     mean_train_score  std_train_score
# 35          0.517518              0.0
# 28          0.992993              0.0
# 30          0.527528              0.0
# 45          0.506507              0.0
# 40          0.506507              0.0
# 0           0.521522              0.0
# 1           0.521522              0.0
# 2           0.521522              0.0
# 3           0.521522              0.0
# 4           0.520521              0.0
# 38          0.826827              0.0
# 41          0.531532              0.0
# 46          0.524525              0.0
# 33          0.960961              0.0
# 21          0.518519              0.0
# 48          0.766767              0.0
# 43          0.767768              0.0
# 37          0.571572              0.0
# 44          0.993994              0.0
# 39          0.994995              0.0
# 49          0.993994              0.0
# 29          1.000000              0.0
# 34          0.997998              0.0
# 42          0.571572              0.0
# 32          0.604605              0.0
# 47          0.559560              0.0
# 27          0.628629              0.0
# 36          0.512513              0.0
# 24          0.526527              0.0
# 26          0.524525              0.0
# 7           0.522523              0.0
# 11          0.522523              0.0
# 15          0.522523              0.0
# 19          0.519520              0.0
# 25          0.511512              0.0
# 17          0.511512              0.0
# 31          0.518519              0.0
# 16          0.529530              0.0
# 12          0.529530              0.0
# 10          0.517518              0.0
# 18          0.519520              0.0
# 8           0.529530              0.0
# 6           0.517518              0.0
# 14          0.517518              0.0
# 20          0.527528              0.0
# 13          0.512513              0.0
# 9           0.512513              0.0
# 23          0.502503              0.0
# 5           0.512513              0.0
# 22          0.508509              0.0

# %% [markdown]
# ## Simulazione Trading
#
# Quanto guadagnerebbe un trader che compra e vende titoli in base alle predizioni del modello?
#
# Ipotizziamo un trader che all'inizio di ogni giornata compra o vende (allo scoperto) un singolo titolo al suo valore di apertura a seconda della predizione del modello, per poi rivenderlo o ricomprarlo al suo valore di chiusura
#
# Siano $O,C,\hat{C}$ rispettivamente il valore di apertura, quello di chiusura reale e quello di chiusura predetto, il guadagno (o perdita se negativo) di ciascuna giornata sarà:
#
# $$ R = \left\{\begin{array}{lr}C-O&:\hat{C}>O\\O-C&:\hat{C}<O\end{array}\right. $$
#
# In forma di funzione abbiamo

# %%
def gain(real, pred):
    real_data = sp500.reindex(index=real.index)
    diff = real_data["Close"] - real_data["Open"]
    return np.where(pred >= 0, diff, -diff).sum()
gain_scorer = make_scorer(gain, greater_is_better=True)

# %%
gs = GridSearchCV(KernelRidge(), param_grid=[
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["linear"]},
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["poly"], "degree": np.linspace(2, 5, 4)},
    {"alpha": np.logspace(-4, 4, 5), "kernel": ["rbf"], "gamma": np.logspace(-4, 4, 5)}
], cv=split, scoring=gain_scorer)
gs.fit(X[["Lag1", "Lag2"]], y)
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise-deprecating',
#        estimator=KernelRidge(alpha=1, coef0=1, degree=3, gamma=None, kernel='linear',
#       kernel_params=None),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['linear']}, {'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['poly'], 'degree': array([2., 3., 4., 5.])}, {'alpha': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04]), 'kernel': ['rbf'], 'gamma': array([1.e-04, 1.e-02, 1.e+00, 1.e+02, 1.e+04])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(gain), verbose=0)

# %%
pd.DataFrame(gs.cv_results_).sort_values("rank_test_score")
# Out:
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 35       0.042487           0.0         0.004573             0.0           1
# 30       0.045742           0.0         0.004804             0.0        0.01
# 37       0.051469           0.0         0.006099             0.0           1
# 21       0.037180           0.0         0.001889             0.0       10000
# 41       0.099801           0.0         0.015269             0.0         100
# 0        0.075425           0.0         0.003908             0.0      0.0001
# 1        0.055296           0.0         0.003404             0.0        0.01
# 2        0.047877           0.0         0.005882             0.0           1
# 3        0.045004           0.0         0.001495             0.0         100
# 4        0.069625           0.0         0.001512             0.0       10000
# 38       0.077921           0.0         0.006453             0.0           1
# 46       0.077126           0.0         0.011027             0.0       10000
# 43       0.091608           0.0         0.012792             0.0         100
# 48       0.104674           0.0         0.006410             0.0       10000
# 28       0.101698           0.0         0.006788             0.0      0.0001
# 42       0.079218           0.0         0.010082             0.0         100
# 36       0.050852           0.0         0.005455             0.0           1
# 27       0.073800           0.0         0.012407             0.0      0.0001
# 32       0.051517           0.0         0.006461             0.0        0.01
# 33       0.109019           0.0         0.018148             0.0        0.01
# 40       0.057548           0.0         0.009040             0.0         100
# 45       0.055053           0.0         0.009869             0.0       10000
# 47       0.086374           0.0         0.012443             0.0       10000
# 25       0.042024           0.0         0.012331             0.0      0.0001
# 12       0.094634           0.0         0.017770             0.0        0.01
# 8        0.105811           0.0         0.019400             0.0      0.0001
# 16       0.097635           0.0         0.037768             0.0           1
# 26       0.078644           0.0         0.011859             0.0      0.0001
# 17       0.055246           0.0         0.003858             0.0         100
# 44       0.095156           0.0         0.011369             0.0         100
# 39       0.099391           0.0         0.014465             0.0           1
# 49       0.050556           0.0         0.005672             0.0       10000
# 29       0.051594           0.0         0.005871             0.0      0.0001
# 34       0.050323           0.0         0.005673             0.0        0.01
# 19       0.105751           0.0         0.017792             0.0         100
# 24       0.097583           0.0         0.020932             0.0       10000
# 13       0.030571           0.0         0.001826             0.0           1
# 9        0.036121           0.0         0.002026             0.0        0.01
# 5        0.034787           0.0         0.001816             0.0      0.0001
# 31       0.048967           0.0         0.005532             0.0        0.01
# 20       0.114327           0.0         0.021427             0.0         100
# 15       0.094476           0.0         0.017770             0.0           1
# 11       0.106247           0.0         0.040332             0.0        0.01
# 7        0.102853           0.0         0.039005             0.0      0.0001
# 18       0.127757           0.0         0.017757             0.0         100
# 10       0.101033           0.0         0.017812             0.0        0.01
# 6        0.107097           0.0         0.021073             0.0      0.0001
# 14       0.114949           0.0         0.017991             0.0           1
# 23       0.096371           0.0         0.017783             0.0       10000
# 22       0.107152           0.0         0.017803             0.0       10000
#
#    param_kernel param_degree param_gamma  \
# 35          rbf          NaN      0.0001
# 30          rbf          NaN      0.0001
# 37          rbf          NaN           1
# 21         poly            2         NaN
# 41          rbf          NaN        0.01
# 0        linear          NaN         NaN
# 1        linear          NaN         NaN
# 2        linear          NaN         NaN
# 3        linear          NaN         NaN
# 4        linear          NaN         NaN
# 38          rbf          NaN         100
# 46          rbf          NaN        0.01
# 43          rbf          NaN         100
# 48          rbf          NaN         100
# 28          rbf          NaN         100
# 42          rbf          NaN           1
# 36          rbf          NaN        0.01
# 27          rbf          NaN           1
# 32          rbf          NaN           1
# 33          rbf          NaN         100
# 40          rbf          NaN      0.0001
# 45          rbf          NaN      0.0001
# 47          rbf          NaN           1
# 25          rbf          NaN      0.0001
# 12         poly            5         NaN
# 8          poly            5         NaN
# 16         poly            5         NaN
# 26          rbf          NaN        0.01
# 17         poly            2         NaN
# 44          rbf          NaN       10000
# 39          rbf          NaN       10000
# 49          rbf          NaN       10000
# 29          rbf          NaN       10000
# 34          rbf          NaN       10000
# 19         poly            4         NaN
# 24         poly            5         NaN
# 13         poly            2         NaN
# 9          poly            2         NaN
# 5          poly            2         NaN
# 31          rbf          NaN        0.01
# 20         poly            5         NaN
# 15         poly            4         NaN
# 11         poly            4         NaN
# 7          poly            4         NaN
# 18         poly            3         NaN
# 10         poly            3         NaN
# 6          poly            3         NaN
# 14         poly            3         NaN
# 23         poly            4         NaN
# 22         poly            3         NaN
#
#                                                params  split0_test_score  \
# 35   {'alpha': 1.0, 'gamma': 0.0001, 'kernel': 'rbf'}         238.659534
# 30  {'alpha': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}         224.860954
# 37      {'alpha': 1.0, 'gamma': 1.0, 'kernel': 'rbf'}         220.480346
# 21  {'alpha': 10000.0, 'degree': 2.0, 'kernel': 'p...         213.620970
# 41   {'alpha': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}         194.240596
# 0               {'alpha': 0.0001, 'kernel': 'linear'}         193.280634
# 1                 {'alpha': 0.01, 'kernel': 'linear'}         193.280634
# 2                  {'alpha': 1.0, 'kernel': 'linear'}         193.280634
# 3                {'alpha': 100.0, 'kernel': 'linear'}         193.280634
# 4              {'alpha': 10000.0, 'kernel': 'linear'}         193.280634
# 38    {'alpha': 1.0, 'gamma': 100.0, 'kernel': 'rbf'}         171.960086
# 46  {'alpha': 10000.0, 'gamma': 0.01, 'kernel': 'r...         157.540398
# 43  {'alpha': 100.0, 'gamma': 100.0, 'kernel': 'rbf'}         150.320434
# 48  {'alpha': 10000.0, 'gamma': 100.0, 'kernel': '...         150.320434
# 28  {'alpha': 0.0001, 'gamma': 100.0, 'kernel': 'r...         100.559940
# 42    {'alpha': 100.0, 'gamma': 1.0, 'kernel': 'rbf'}          96.940792
# 36     {'alpha': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}          59.380486
# 27   {'alpha': 0.0001, 'gamma': 1.0, 'kernel': 'rbf'}          57.561408
# 32     {'alpha': 0.01, 'gamma': 1.0, 'kernel': 'rbf'}          45.561650
# 33   {'alpha': 0.01, 'gamma': 100.0, 'kernel': 'rbf'}          41.499886
# 40  {'alpha': 100.0, 'gamma': 0.0001, 'kernel': 'r...          35.879762
# 45  {'alpha': 10000.0, 'gamma': 0.0001, 'kernel': ...          35.879762
# 47  {'alpha': 10000.0, 'gamma': 1.0, 'kernel': 'rbf'}          28.500850
# 25  {'alpha': 0.0001, 'gamma': 0.0001, 'kernel': '...           1.900264
# 12   {'alpha': 0.01, 'degree': 5.0, 'kernel': 'poly'}         -20.539184
# 8   {'alpha': 0.0001, 'degree': 5.0, 'kernel': 'po...         -20.539184
# 16    {'alpha': 1.0, 'degree': 5.0, 'kernel': 'poly'}         -20.539184
# 26  {'alpha': 0.0001, 'gamma': 0.01, 'kernel': 'rbf'}         -23.919320
# 17  {'alpha': 100.0, 'degree': 2.0, 'kernel': 'poly'}         -29.039678
# 44  {'alpha': 100.0, 'gamma': 10000.0, 'kernel': '...         -29.539672
# 39  {'alpha': 1.0, 'gamma': 10000.0, 'kernel': 'rbf'}         -29.539672
# 49  {'alpha': 10000.0, 'gamma': 10000.0, 'kernel':...         -29.539672
# 29  {'alpha': 0.0001, 'gamma': 10000.0, 'kernel': ...         -35.059690
# 34  {'alpha': 0.01, 'gamma': 10000.0, 'kernel': 'r...         -35.059690
# 19  {'alpha': 100.0, 'degree': 4.0, 'kernel': 'poly'}         -44.839978
# 24  {'alpha': 10000.0, 'degree': 5.0, 'kernel': 'p...         -50.739634
# 13    {'alpha': 1.0, 'degree': 2.0, 'kernel': 'poly'}         -51.739872
# 9    {'alpha': 0.01, 'degree': 2.0, 'kernel': 'poly'}         -51.739872
# 5   {'alpha': 0.0001, 'degree': 2.0, 'kernel': 'po...         -51.739872
# 31    {'alpha': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}         -52.099500
# 20  {'alpha': 100.0, 'degree': 5.0, 'kernel': 'poly'}         -54.879274
# 15    {'alpha': 1.0, 'degree': 4.0, 'kernel': 'poly'}         -56.419810
# 11   {'alpha': 0.01, 'degree': 4.0, 'kernel': 'poly'}         -56.419810
# 7   {'alpha': 0.0001, 'degree': 4.0, 'kernel': 'po...         -56.419810
# 18  {'alpha': 100.0, 'degree': 3.0, 'kernel': 'poly'}        -103.079724
# 10   {'alpha': 0.01, 'degree': 3.0, 'kernel': 'poly'}        -103.079724
# 6   {'alpha': 0.0001, 'degree': 3.0, 'kernel': 'po...        -103.079724
# 14    {'alpha': 1.0, 'degree': 3.0, 'kernel': 'poly'}        -103.079724
# 23  {'alpha': 10000.0, 'degree': 4.0, 'kernel': 'p...        -141.538944
# 22  {'alpha': 10000.0, 'degree': 3.0, 'kernel': 'p...        -196.099006
#
#     mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 35       238.659534    0.000000e+00                1         -152.358272
# 30       224.860954    0.000000e+00                2          262.960690
# 37       220.480346    0.000000e+00                3         2657.818228
# 21       213.620970    0.000000e+00                4          340.941906
# 41       194.240596    0.000000e+00                5          417.841312
# 0        193.280634    0.000000e+00                6          261.820194
# 1        193.280634    0.000000e+00                6          261.820194
# 2        193.280634    0.000000e+00                6          261.820194
# 3        193.280634    0.000000e+00                6          261.820194
# 4        193.280634    0.000000e+00                6          250.560184
# 38       171.960086    0.000000e+00               11         7871.400748
# 46       157.540398    0.000000e+00               12          111.041266
# 43       150.320434    0.000000e+00               13         7082.400990
# 48       150.320434    0.000000e+00               13         7065.500966
# 28       100.559940    1.421085e-14               15         9417.541392
# 42        96.940792    1.421085e-14               16         2031.638906
# 36        59.380486    0.000000e+00               17          545.957386
# 27        57.561408    0.000000e+00               18         4192.201546
# 32        45.561650    0.000000e+00               19         3512.699342
# 33        41.499886    0.000000e+00               20         9249.900884
# 40        35.879762    0.000000e+00               21          -75.340092
# 45        35.879762    0.000000e+00               21          -75.340092
# 47        28.500850    0.000000e+00               23         1799.598134
# 25         1.900264    0.000000e+00               24          477.078368
# 12       -20.539184    0.000000e+00               25         1257.016944
# 8        -20.539184    0.000000e+00               25         1257.016944
# 16       -20.539184    0.000000e+00               25         1257.016944
# 26       -23.919320    0.000000e+00               28          920.077874
# 17       -29.039678    0.000000e+00               29          675.117424
# 44       -29.539672    0.000000e+00               30         9416.361092
# 39       -29.539672    0.000000e+00               30         9419.901132
# 49       -29.539672    0.000000e+00               30         9416.361092
# 29       -35.059690    0.000000e+00               33         9424.920908
# 34       -35.059690    0.000000e+00               33         9424.421152
# 19       -44.839978    0.000000e+00               35          569.418338
# 24       -50.739634    0.000000e+00               36         1009.098994
# 13       -51.739872    0.000000e+00               37          703.297722
# 9        -51.739872    0.000000e+00               37          703.297722
# 5        -51.739872    0.000000e+00               37          703.297722
# 31       -52.099500    0.000000e+00               40          649.878666
# 20       -54.879274    0.000000e+00               41         1223.496316
# 15       -56.419810    0.000000e+00               42          635.338134
# 11       -56.419810    0.000000e+00               42          635.338134
# 7        -56.419810    0.000000e+00               42          635.338134
# 18      -103.079724    1.421085e-14               45          575.358400
# 10      -103.079724    1.421085e-14               45          487.378418
# 6       -103.079724    1.421085e-14               45          487.378418
# 14      -103.079724    1.421085e-14               45          487.378418
# 23      -141.538944    0.000000e+00               49          207.896594
# 22      -196.099006    0.000000e+00               50          289.938596
#
#     mean_train_score  std_train_score
# 35       -152.358272              0.0
# 30        262.960690              0.0
# 37       2657.818228              0.0
# 21        340.941906              0.0
# 41        417.841312              0.0
# 0         261.820194              0.0
# 1         261.820194              0.0
# 2         261.820194              0.0
# 3         261.820194              0.0
# 4         250.560184              0.0
# 38       7871.400748              0.0
# 46        111.041266              0.0
# 43       7082.400990              0.0
# 48       7065.500966              0.0
# 28       9417.541392              0.0
# 42       2031.638906              0.0
# 36        545.957386              0.0
# 27       4192.201546              0.0
# 32       3512.699342              0.0
# 33       9249.900884              0.0
# 40        -75.340092              0.0
# 45        -75.340092              0.0
# 47       1799.598134              0.0
# 25        477.078368              0.0
# 12       1257.016944              0.0
# 8        1257.016944              0.0
# 16       1257.016944              0.0
# 26        920.077874              0.0
# 17        675.117424              0.0
# 44       9416.361092              0.0
# 39       9419.901132              0.0
# 49       9416.361092              0.0
# 29       9424.920908              0.0
# 34       9424.421152              0.0
# 19        569.418338              0.0
# 24       1009.098994              0.0
# 13        703.297722              0.0
# 9         703.297722              0.0
# 5         703.297722              0.0
# 31        649.878666              0.0
# 20       1223.496316              0.0
# 15        635.338134              0.0
# 11        635.338134              0.0
# 7         635.338134              0.0
# 18        575.358400              0.0
# 10        487.378418              0.0
# 6         487.378418              0.0
# 14        487.378418              0.0
# 23        207.896594              0.0
# 22        289.938596              0.0

# %%
model = LinearRegression()
model.fit(X_train[["Lag1", "Lag2"]], y_train)
gain(y_val, model.predict(X_val[["Lag1", "Lag2"]]))
# Out:
# /home/pasolini/.virtualenvs/dia/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
# 218.64074000000028
